# %%
from ultralytics import YOLO
import shutil

shutil.rmtree("./runs", ignore_errors=True)

# Modell laden (z.B. YOLOv12x-seg)
model = YOLO('./yolov12x-seg.pt')

# Training starten
model.train(data='./train.yaml', epochs=500, imgsz=720, batch=8)

results = model.val()

model.save('./model/yolo12x-seg.pt')
# Out:
# Ultralytics 8.3.186 🚀 Python-3.12.11 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24117MiB)
# ...
